# %%
import pandas as pd

# %%
df=pd.read_csv("D:/Adaptive Learning in MCQ Selection/Questions.csv")
df.head()
# Out:
#                                             question  cop  \
# 0  Chronic urethral obstruction due to benign pri...    3
# 1  Which vitamin is supplied from only animal sou...    3
# 2  All of the following are surgical options for ...    4
# 3  Following endaerectomy on the right common car...    1
# 4   Growth hormone has its effect on growth through?    2
#
#                           opa                        opb              opc  \
# 0                 Hyperplasia                  Hyperophy          Atrophy
# 1                   Vitamin C                 Vitamin B7      Vitamin B12
# 2  Adjustable gastric banding  Biliopancreatic diversion  Duodenal Switch
# 3  Central aery of the retina          Infraorbital aery    Lacrimal aery
# 4                    Directly                      IG1-1        Thyroxine
#
#                           opd                                    id  \
# 0                    Dyplasia  e9ad821a-c438-4965-9f77-760819dfa155
# ...

# %%
filtered_df = df[df['Difficulty'] == 0]
beginner_level_rows = filtered_df.sample(n=10, random_state=42)
beginner_level_df = pd.DataFrame(beginner_level_rows)
beginner_level_df.reset_index(drop=True, inplace=True)

# %%
beginner_level_df
# Out:
#                                             question  cop  \
# 0  Syndrome associated with thymic and parathyroi...    3
# 1  All of the following cause high anion gap meta...    4
# 2  In a population of 10,000, beta carotene was g...    1
# 3  Ligaments for antero-posterior stability of kn...    1
# 4  Organism implicated in Cellulitis following an...    3
# 5                  Mechanism of action of zileuton:-    2
# 6  Antlepileptic of choice in Post diabetic Perip...    1
# 7          Galactosemia is due to the deficiency of:    3
# 8  Culture media containing egg or serum is typic...    1
# 9  Chloroquine is given as 600 mg loading dose be...    3
#
#                                                  opa  \
# 0                              Prader Willi syndrome
# 1                                    Lactic acidosis
# 2  Beta carotene and lung cancer have no relation...
# 3                                 Cruciate ligaments
# 4                                       Staph.aureus
# ...

# %%
df.rename(columns={'question': 'Question',
                  'opa': 'A',
                  'opb': 'B',
                  'opc': 'C',
                  'opd': 'D',
                  'cop': 'Answer'}, inplace=True)

# %%
replacement_dict = {1: 'A', 2: 'B', 3: 'C', 4: 'D'}

# %%
df['Answer'] = df['Answer'].replace(replacement_dict)

# %%
df
# Out:
#                                                  Question Answer  \
# 0       Chronic urethral obstruction due to benign pri...      C
# 1       Which vitamin is supplied from only animal sou...      C
# 2       All of the following are surgical options for ...      D
# 3       Following endaerectomy on the right common car...      A
# 4        Growth hormone has its effect on growth through?      B
# ...                                                   ...    ...
# 180061  Most common site for extra mammary Paget&;s di...      A
# 180062       Inferior Rib notching is seen in all except?      D
# 180063  Which is false regarding cryptococcus neoformans?      C
# 180064  Histopathological finding of gluten hypersensi...      A
# 180065  All except one are centrally acting muscle blo...      D
#
#                                  A                                    B  \
# 0                      Hyperplasia                            Hyperophy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180066 entries, 0 to 180065
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Question    180066 non-null  object
#  1   Answer      180066 non-null  object
#  2   A           180066 non-null  object
#  3   B           180066 non-null  object
#  4   C           180066 non-null  object
#  5   D           180066 non-null  object
#  6   id          180066 non-null  object
#  7   Difficulty  180066 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 11.0+ MB

# %%
df.to_excel("Question_Dev.xlsx",index=False)

# %%
df1=pd.read_excel("./Question_Dev.xlsx")
df1
# Out:
#                                                  Question Answer  \
# 0       Chronic urethral obstruction due to benign pri...      C
# 1       Which vitamin is supplied from only animal sou...      C
# 2       All of the following are surgical options for ...      D
# 3       Following endaerectomy on the right common car...      A
# 4        Growth hormone has its effect on growth through?      B
# ...                                                   ...    ...
# 180061  Most common site for extra mammary Paget&;s di...      A
# 180062       Inferior Rib notching is seen in all except?      D
# 180063  Which is false regarding cryptococcus neoformans?      C
# 180064  Histopathological finding of gluten hypersensi...      A
# 180065  All except one are centrally acting muscle blo...      D
#
#                                  A                                    B  \
# 0                      Hyperplasia                            Hyperophy
# ...
